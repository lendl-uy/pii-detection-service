# %%
import torch
import json
from transformers import AutoTokenizer, AutoModelForTokenClassification
from pathlib import Path

# %%
# Sample text
sample_text = """John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123-45-6789."""

# %%
# Paths and configurations
DEBERTA_MODEL_PATH = "models/deberta3base_1024"
INFERENCE_MAX_LENGTH = 2048

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(DEBERTA_MODEL_PATH)
model = AutoModelForTokenClassification.from_pretrained(DEBERTA_MODEL_PATH)

# Load id2label mapping
config = json.load(open(Path(DEBERTA_MODEL_PATH) / "config.json"))
id2label = config["id2label"]

# # Tokenize the sample text
# inputs = tokenizer(sample_text, return_tensors="pt", truncation=True, max_length=INFERENCE_MAX_LENGTH)

# Tokenize the sample text and prepare inputs
inputs = tokenizer(sample_text, return_tensors="pt", truncation=True, max_length=INFERENCE_MAX_LENGTH, padding=True)

# Retrieve tokens from IDs
tokens = tokenizer.convert_ids_to_tokens(inputs.input_ids[0])

# Predict
model.eval()
with torch.no_grad():
    outputs = model(**inputs)
logits = outputs.logits

# Obtain predictions for non-special, non-padded tokens
predictions = logits.argmax(dim=-1).squeeze(0)  # Remove the batch dimension
active_tokens = inputs['attention_mask'].squeeze(0) == 1  # Identify non-padded tokens

# Filter out predictions for special and padded tokens
filtered_predictions = predictions[active_tokens]

# Convert predictions to labels
pred_labels = [id2label[str(pred.item())] for pred in filtered_predictions]

# %%
def reconstruct_text(tokens, labels):
    # Initialize an empty string for the reconstructed text
    reconstructed_text = ""
    # Loop through each token and corresponding label
    for token, label in zip(tokens, labels):
        # Skip special tokens
        if token in ["[CLS]", "[SEP]"]:
            continue
        # Remove the first underscore and any subsequent underscores (subword pieces)
        if token.startswith("▁"):
            # Add a space before starting a new word (if not the start of the string)
            if reconstructed_text:
                reconstructed_text += " "
            # Add the cleaned token (without the underscore)
            reconstructed_text += token[1:]
        else:
            # Directly append subword pieces to the last word (no space)
            reconstructed_text += token
    
    return reconstructed_text

# %%
reconstruct_text(tokens, pred_labels)
# Out:
# reconstructed_text =
# WITH UNDERSCORE
# reconstructed_text = John
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1
# reconstructed_text = John Doe was born on January 1,
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990
# reconstructed_text = John Doe was born on January 1, 1990,
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City
# reconstructed_text = John Doe was born on January 1, 1990, in New York City.
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science.
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John'
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is john
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndo
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com,
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555)
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-45
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567.
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently,
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St,
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York,
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 1000
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001.
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at Tech
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions,
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer.
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is
# WITH UNDERSCORE
# Adding space!!!!!!!
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123-
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123-45
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123-45-
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123-45-6
# reconstructed_text = John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123-45-6789
# "John Doe was born on January 1, 1990, in New York City. He has lived in NYC all his life and graduated from Columbia University in 2012 with a degree in Computer Science. John's email address is johndoe@example.com, and his phone number is (555) 123-4567. Recently, he moved to a new house located at 123 Main St, New York, NY 10001. John works at TechSolutions, where he is a senior software engineer. His Social Security number is 123-45-6789."

# %%
for token, label in zip(tokens, pred_labels):
    print(f"{token}: {label}")
# Out:
# [CLS]: O
# ▁John: B-NAME_STUDENT
# ▁Doe: I-NAME_STUDENT
# ▁was: O
# ▁born: O
# ▁on: O
# ▁January: O
# ▁1: O
# ,: O
# ▁1990: O
# ,: O
# ▁in: O
# ▁New: O
# ▁York: O
# ▁City: O
# .: O
# ▁He: O
# ▁has: O
# ▁lived: O
# ▁in: O
# ▁NYC: O
# ▁all: O
# ▁his: O
# ▁life: O
# ▁and: O
# ▁graduated: O
# ▁from: O
# ▁Columbia: O
# ▁University: O
# ▁in: O
# ▁2012: O
# ▁with: O
# ▁a: O
# ▁degree: O
# ▁in: O
# ▁Computer: O
# ▁Science: O
# .: O
# ▁John: B-NAME_STUDENT
# ': O
# s: O
# ▁email: O
# ▁address: O
# ▁is: O
# ▁john: B-EMAIL
# do: B-EMAIL
# e: B-EMAIL
# @: B-EMAIL
# example: B-EMAIL
# .: B-EMAIL
# com: B-EMAIL
# ,: O
# ▁and: O
# ▁his: O
# ▁phone: O
# ▁number: O
# ▁is: O
# ▁(: O
# 555: O
# ): O
# ▁123: O
# -: O
# 45: O
# 67: O
# .: O
# ▁Recently: O
# ,: O
# ▁he: O
# ▁moved: O
# ▁to: O
# ▁a: O
# ▁new: O
# ▁house: O
# ▁located: O
# ▁at: O
# ▁123: B-STREET_ADDRESS
# ▁Main: I-STREET_ADDRESS
# ▁St: I-STREET_ADDRESS
# ,: O
# ▁New: O
# ▁York: O
# ,: O
# ▁NY: O
# ▁1000: O
# 1: O
# .: O
# ▁John: O
# ▁works: O
# ▁at: O
# ▁Tech: O
# Solutions: O
# ,: O
# ▁where: O
# ▁he: O
# ▁is: O
# ▁a: O
# ▁senior: O
# ▁software: O
# ▁engineer: O
# .: O
# ▁His: O
# ▁Social: O
# ▁Security: O
# ▁number: O
# ▁is: O
# ▁123: O
# -: O
# 45: O
# -: O
# 6: O
# 789: O
# .: O
# [SEP]: O

# %%
tokens
# Out:
# ['[CLS]',
#  '▁John',
#  '▁Doe',
#  '▁was',
#  '▁born',
#  '▁on',
#  '▁January',
#  '▁1',
#  ',',
#  '▁1990',
#  ',',
#  '▁in',
#  '▁New',
#  '▁York',
#  '▁City',
#  '.',
#  '▁He',
#  '▁has',
#  '▁lived',
#  '▁in',
#  '▁NYC',
#  '▁all',
#  '▁his',
#  '▁life',
#  '▁and',
#  '▁graduated',
#  '▁from',
#  '▁Columbia',
#  '▁University',
#  '▁in',
#  '▁2012',
#  '▁with',
#  '▁a',
#  '▁degree',
#  '▁in',
#  '▁Computer',
#  '▁Science',
#  '.',
#  '▁John',
#  "'",
#  's',
#  '▁email',
#  '▁address',
#  '▁is',
#  '▁john',
#  'do',
#  'e',
#  '@',
#  'example',
#  '.',
#  'com',
#  ',',
#  '▁and',
#  '▁his',
#  '▁phone',
#  '▁number',
#  '▁is',
#  '▁(',
#  '555',
#  ')',
#  '▁123',
#  '-',
#  '45',
#  '67',
#  '.',
#  '▁Recently',
#  ',',
#  '▁he',
#  '▁moved',
#  '▁to',
#  '▁a',
#  '▁new',
#  '▁house',
#  '▁located',
#  '▁at',
#  '▁123',
#  '▁Main',
#  '▁St',
#  ',',
#  '▁New',
#  '▁York',
#  ',',
#  '▁NY',
#  '▁1000',
#  '1',
#  '.',
#  '▁John',
#  '▁works',
#  '▁at',
#  '▁Tech',
#  'Solutions',
#  ',',
#  '▁where',
#  '▁he',
#  '▁is',
#  '▁a',
#  '▁senior',
#  '▁software',
#  '▁engineer',
#  '.',
#  '▁His',
#  '▁Social',
#  '▁Security',
#  '▁number',
#  '▁is',
#  '▁123',
#  '-',
#  '45',
#  '-',
#  '6',
#  '789',
#  '.',
#  '[SEP]']

# %%
def clean_tokens_deberta(tokens):
    # Remove [CLS] and [SEP]
    removed_stream_identifiers = tokens[1:-1]
    removed_underscores = [token[1:] if (token.startswith("▁") and len(token) > 1) else token for token in removed_stream_identifiers]
    print(removed_underscores)
    return removed_underscores

# %%
tokens = ['[CLS]', '▁John', '▁Doe', '▁was', '▁born', '▁on', '▁January', '▁1', ',', '▁1990', ',', '▁in', '▁New', '▁York', '▁City', '.', '▁He', '▁has', '▁lived', '▁in', '▁NYC', '▁all', '▁his', '▁life', '▁and', '▁graduated', '▁from', '▁Columbia', '▁University', '▁in', '▁2012', '▁with', '▁a', '▁degree', '▁in', '▁Computer', '▁Science', '.', '▁John', "'", 's', '▁email', '▁address', '▁is', '▁john', 'do', 'e', '@', 'example', '.', 'com', ',', '▁and', '▁his', '▁phone', '▁number', '▁is', '▁(', '555', ')', '▁123', '-', '45', '67', '.', '▁Recently', ',', '▁he', '▁moved', '▁to', '▁a', '▁new', '▁house', '▁located', '▁at', '▁123', '▁Main', '▁St', ',', '▁New', '▁York', ',', '▁NY', '▁1000', '1', '.', '▁John', '▁works', '▁at', '▁Tech', 'Solutions', ',', '▁where', '▁he', '▁is', '▁a', '▁senior', '▁software', '▁engineer', '.', '▁His', '▁Social', '▁Security', '▁number', '▁is', '▁123', '-', '45', '-', '6', '789', '.', '[SEP]']
cleaned_tokens = clean_tokens_deberta(tokens)
# Out:
# ['John', 'Doe', 'was', 'born', 'on', 'January', '1', ',', '1990', ',', 'in', 'New', 'York', 'City', '.', 'He', 'has', 'lived', 'in', 'NYC', 'all', 'his', 'life', 'and', 'graduated', 'from', 'Columbia', 'University', 'in', '2012', 'with', 'a', 'degree', 'in', 'Computer', 'Science', '.', 'John', "'", 's', 'email', 'address', 'is', 'john', 'do', 'e', '@', 'example', '.', 'com', ',', 'and', 'his', 'phone', 'number', 'is', '(', '555', ')', '123', '-', '45', '67', '.', 'Recently', ',', 'he', 'moved', 'to', 'a', 'new', 'house', 'located', 'at', '123', 'Main', 'St', ',', 'New', 'York', ',', 'NY', '1000', '1', '.', 'John', 'works', 'at', 'Tech', 'Solutions', ',', 'where', 'he', 'is', 'a', 'senior', 'software', 'engineer', '.', 'His', 'Social', 'Security', 'number', 'is', '123', '-', '45', '-', '6', '789', '.']
